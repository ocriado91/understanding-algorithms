# %% [markdown]
# <a href="https://colab.research.google.com/github/ocriado91/SalesmanProblemGA/blob/1-create-google-colab-notebook-with-code-and-introduction-to-ga/SalesmanProblemGA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Salesman Problem using Genetic Algorithms
#
# <p align="center">
# <img width=200px src="https://drive.google.com/uc?export=view&id=1PFCZg_MfegudSuZ9foSByELWZT9aBwlq">
# </p>
#
# In this notebook, we are going to resolve the _Salesman Problem_ using _Genetic Algorithms_ explaining step to step each stage of the algorithm and a brief introduction to the _Genetic Algorithms_

# %% [markdown]
# ## The Traveling Salesman Problem (TSP)
#
# This is a classic problem in computer science and mathematics. It asks the question: given a list of cities and the distances between each pair of cities, what is the shortest possible route that visits each city exactly once and returns to the origin city?
#
# Imagine a salesperson who needs to visit a bunch of cities to make sales. They want to find the most efficient route that allows them to visit every city exactly once and get back to their starting point, minimizing travel time or distance. This is the essence of the TSP.

# %% [markdown]
# ## Introduction to Genetic Algorithms
#
# A _Genetic Algorithm_ (GA) is a search heuristic that is inspired by Charles Darwin's theory of natural selection where the fittest individuals are selected for reprduction in order to produce offspring of the next generation. If the parents are the fittest from a set of individuals, they are going to produce offspring which inherit their characteristics and will be added to the next generation and their offspring will be better chance of surviving.

# %% [markdown]
# ## Hands-on

# %% [markdown]
# ### Imports

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Constants

# %%
POPULATION_SIZE = 100
MUTATION_RATE = 0.01
NUM_GENERATIONS = 5

# %% [markdown]
# ### City class
#
# The first step is to create a __City__ class with coordinates (X,Y) where our Travelling Salesman must be visit. Also, we are going to create a couple of methods to compute the distance between the current city and another one, and a method to plot the city into a 2D plot:

# %%
class City:
  '''
  City to be visited from the Salesman
  '''

  def __init__(self, name, x_pos, y_pos):
    self.name = name
    self.x_pos = x_pos
    self.y_pos = y_pos

  def distance_to(self, another_city) -> float:
    '''
    Compute the cartesian distance between
    the current city and another_city
    '''

    x_diff = abs(self.x_pos - another_city.x_pos)
    y_diff = abs(self.y_pos - another_city.y_pos)
    return (x_diff**2 + y_diff**2) ** 0.5

  def plot_city(self):
    '''
    Plot the position of current city
    into a 2D cartesian plot
    '''

    plt.scatter(self.x_pos, self.y_pos, label=self.name)

# %% [markdown]
# And now we can create the set of Cities where our Salesman must be to visit in her journey:

# %%
cities = [
        City('A', 1, 1),
        City('B', 1, 2),
        City('C', 2, 3),
        City('D', 3, -1),
        City('E', 4, 5),
        City('F', 3, 2),
    ]

# %% [markdown]
# ### Genetic Algorithm
#
# A _Genetic Algorithm_ is compound by five stages:

# %% [markdown]
# #### 1. Initial population
# Genetic algorithms start with a random initial population:

# %%
def initial_population()-> list:
  population = []
  for _ in range(POPULATION_SIZE):
    individual = random.sample(cities, len(cities))
    population.append(individual)
  return population

# Call to the previous function
population = initial_population()

# %% [markdown]
# #### 2. Selection
#
# Selection is the process of choosing chromosomes to use as parents for the next generation based into a _fitness function_:

# %%
def fitness_function(individual: list[City]) -> float:
  '''
  This function computes the fitness score within
  an individual set of cities
  '''
  try:
    total_distance = 0
    for idy in range(len(individual)-1):
      current_city = individual[idy]
      next_city = individual[idy+1]
      total_distance += current_city.distance_to(next_city)
    score = 1/total_distance
    return score
  except ZeroDivisionError:
    return 10000

# %%
def selection(population: list):
  weights = []
  for idx in range(len(population)):
    individual = population[idx]
    score = fitness_function(individual)
    weights.append(score)

  # Copy population variable into a new one
  selection_population = population[:]
  sample = []
  for _ in range(2):
    while True:
      selected = random.choices(selection_population,
                                weights=weights)[0]
      # Detect duplicate city into selected set
      if len(set(selected)) != len(selection_population[0]):
        #print("Detected duplicated items:", [x.name for x in selected])
        continue

      sample.append(selected)
      # Remove selected parent from population
      # and weights list
      index = selection_population.index(selected)
      selection_population.pop(index)
      weights.pop(index)
      break

  parent1 = sample[0]
  parent2 = sample[1]

  return parent1, parent2

parent1, parent2 = selection(population)

# %% [markdown]
# #### 3. Crossover
#
# Crossover combines the chromosomes of parents to form children. There are several crossover schemas, but for simplify, we are going to implement a random parent selection to avoid duplicated genes into the child:

# %%
def crossover(parent1: list[City],
              parent2: list[City]) -> list:
  crossover_point = random.randint(0, len(parent1)-1)

  if crossover_point % 2 == 0:
    return parent1
  else:
    return parent2

child = crossover(parent1, parent2)

# %% [markdown]
# #### 4. Mutation
# In childs were produced only through crossover, many traits that were not present in the initial random population could new occur. Mutation allows new traits to spontaneously appear, allowing the genetic algorithm to explore more of the state space:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1IA0xVlbVfmmvi9i3Ty8UfF8wqkLKEiSc">
# </p>

# %%
def mutation(child: list) -> list:
  previous_child = child[:]
  for idx in range(len(child)):
    if random.random() < MUTATION_RATE:
      mutant_index = random.randint(0, len(cities)-1)
      child[idx] = previous_child[mutant_index]
      child[mutant_index] = previous_child[idx]
  return child

print("Incoming child:", [x.name for x in child])
child = mutation(child)
print("Mutant child:", [x.name for x in child])
# Out:
# Incoming child: ['E', 'F', 'A', 'C', 'B', 'D']
# Mutant child: ['E', 'F', 'A', 'C', 'B', 'D']

# %% [markdown]
# ### Iterative process

# %%
def compute_total_distance(cities: list[City]) -> float:
  '''
  Compute the total distance between cities
  '''

  total_distance = 0
  for idx in range(len(cities)-1):
    current_city = cities[idx]
    next_city = cities[idx+1]
    total_distance += current_city.distance_to(next_city)

  return total_distance

# %%
# Create an initial population
population = initial_population()

# Check generations
for generation in range(NUM_GENERATIONS):
  print("Starting generation:", generation)
  new_population = []
  for _ in range(len(population)):
    parent1, parent2 = selection(population)
    child = crossover(parent1, parent2)
    child = mutation(child)
    print("+++++++++++++++++++++++++++++++++++++++++++")
    print("Child after mutation:", [x.name for x in child])
    new_population.append(child)
    print("Fitness score: ", fitness_function(child))
    print("Total distance: ", compute_total_distance(child))

  population += new_population

best_individual = max(population, key=fitness_function)

print("+++++++++++++++++++++++++++++++++++++++++++")
print("Best individual:", [x.name for x in best_individual])
print("Best fitness score:", fitness_function(best_individual))
print("Total best distance: ", compute_total_distance(best_individual))
print("+++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Child after mutation: ['B', 'F', 'D', 'A', 'C', 'E']
# Fitness score:  0.07756193533118777
# Total distance:  12.89292222699217
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'F', 'A', 'D']
# Fitness score:  0.07202728790843992
# Total distance:  13.88362701190674
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'B', 'A']
# Fitness score:  0.07515887765462095
# Total distance:  13.305148123623125
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'C', 'B', 'F', 'E']
# Fitness score:  0.07392062595415673
# Total distance:  13.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'D', 'C', 'A', 'E']
# Fitness score:  0.06112778213988983
# Total distance:  16.35917360311745
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'E', 'C', 'B']
# Fitness score:  0.08019623409290354
# Total distance:  12.469413449533645
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'C', 'F', 'E', 'A']
# Fitness score:  0.0685107191778098
# Total distance:  14.59625606037856
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'A', 'E']
# Fitness score:  0.07322330470336312
# Total distance:  13.65685424949238
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'C', 'F', 'A', 'E']
# Fitness score:  0.061054017853779896
# Total distance:  16.378938440954535
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'F', 'B', 'C', 'D', 'E']
# Fitness score:  0.06306701306342927
# Total distance:  15.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'C', 'A', 'F']
# Fitness score:  0.06168364496788893
# Total distance:  16.21175273479018
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'F', 'D']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'D', 'C', 'A', 'F']
# Fitness score:  0.05285232140206281
# Total distance:  18.920644798034743
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'B', 'D', 'E']
# Fitness score:  0.06187946590620513
# Total distance:  16.16044976076179
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'E', 'C', 'D', 'F']
# Fitness score:  0.0626899004408959
# Total distance:  15.95153275036385
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'E', 'B', 'D', 'A']
# Fitness score:  0.06702745411757192
# Total distance:  14.91925977444875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'B', 'A', 'C', 'D', 'E']
# Fitness score:  0.06475871881350707
# Total distance:  15.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'C', 'E', 'B', 'F']
# Fitness score:  0.06241184108136212
# Total distance:  16.022600562229325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'B', 'D', 'E', 'C']
# Fitness score:  0.06348074212286256
# Total distance:  15.75280890800819
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'D', 'F', 'B', 'A']
# Fitness score:  0.07721093860276165
# Total distance:  12.951532750363851
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'E', 'D', 'F']
# Fitness score:  0.05639189729878967
# Total distance:  17.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'A', 'C']
# Fitness score:  0.0588100483735406
# Total distance:  17.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'B', 'A']
# Fitness score:  0.07515887765462095
# Total distance:  13.305148123623125
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'D', 'E', 'C', 'F']
# Fitness score:  0.06697495464719028
# Total distance:  14.930954492881495
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'D', 'A', 'B']
# Fitness score:  0.0690241597982128
# Total distance:  14.487680877585884
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'E', 'D', 'F']
# Fitness score:  0.05639189729878967
# Total distance:  17.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'C', 'E', 'B']
# Fitness score:  0.07380195545922741
# Total distance:  13.54977647648455
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'F', 'D', 'C', 'A']
# Fitness score:  0.059651307267843665
# Total distance:  16.764091950405113
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'E', 'A', 'F', 'B']
# Fitness score:  0.06177567737254013
# Total distance:  16.18760072786364
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'F', 'B', 'E', 'D', 'C']
# Fitness score:  0.05352007752730946
# Total distance:  18.684576820534954
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'C', 'F', 'A', 'E']
# Fitness score:  0.061054017853779896
# Total distance:  16.378938440954535
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'F', 'A', 'B', 'E']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'A', 'C', 'F']
# Fitness score:  0.06677490987603654
# Total distance:  14.97568475729039
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'F', 'A', 'B', 'D']
# Fitness score:  0.077928206694922
# Total distance:  12.83232403787835
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'D', 'E', 'C', 'F']
# Fitness score:  0.06697495464719028
# Total distance:  14.930954492881495
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'F', 'D', 'B', 'C']
# Fitness score:  0.06179689616581195
# Total distance:  16.182042498005465
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'E', 'A']
# Fitness score:  0.05913244546351071
# Total distance:  16.91118965504441
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'E', 'C', 'B']
# Fitness score:  0.08019623409290354
# Total distance:  12.469413449533645
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'D', 'F', 'B', 'A']
# Fitness score:  0.07721093860276165
# Total distance:  12.951532750363851
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'A', 'D', 'B', 'F']
# Fitness score:  0.07408245086513239
# Total distance:  13.498473502456159
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'D', 'E', 'C', 'F']
# Fitness score:  0.06697495464719028
# Total distance:  14.930954492881495
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'B', 'C', 'F', 'A']
# Fitness score:  0.06778370181811108
# Total distance:  14.75280890800819
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'F', 'A', 'D']
# Fitness score:  0.07202728790843992
# Total distance:  13.88362701190674
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'D', 'A', 'B']
# Fitness score:  0.0690241597982128
# Total distance:  14.487680877585884
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'C', 'D', 'B', 'E']
# Fitness score:  0.060814549307647944
# Total distance:  16.443433543200516
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'D', 'C', 'F']
# Fitness score:  0.07348409477262549
# Total distance:  13.608386999856233
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'F', 'A', 'B', 'D']
# Fitness score:  0.077928206694922
# Total distance:  12.83232403787835
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'F', 'E', 'D', 'C']
# Fitness score:  0.06109427489443207
# Total distance:  16.36814581608426
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'B', 'E', 'D', 'C']
# Fitness score:  0.056546447797315755
# Total distance:  17.684576820534954
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'D', 'B', 'C', 'E']
# Fitness score:  0.07744321495436342
# Total distance:  12.912687064829255
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'D', 'C', 'A', 'F']
# Fitness score:  0.05285232140206281
# Total distance:  18.920644798034743
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'E', 'B', 'C', 'F']
# Fitness score:  0.06256938371005648
# Total distance:  15.982257466909886
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'F', 'C', 'E', 'B', 'D']
# Fitness score:  0.0697987670900229
# Total distance:  14.32690062720235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'C', 'B', 'F', 'E']
# Fitness score:  0.07392062595415673
# Total distance:  13.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'B', 'A', 'C', 'E']
# Fitness score:  0.09037918050115185
# Total distance:  11.06449510224598
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'C', 'E', 'B', 'F']
# Fitness score:  0.06241184108136212
# Total distance:  16.022600562229325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'D', 'C', 'F']
# Fitness score:  0.07348409477262549
# Total distance:  13.608386999856233
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'F', 'A', 'D']
# Fitness score:  0.07202728790843992
# Total distance:  13.88362701190674
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'A', 'C']
# Fitness score:  0.0588100483735406
# Total distance:  17.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'C', 'A', 'F']
# Fitness score:  0.06168364496788893
# Total distance:  16.21175273479018
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'D', 'F', 'A', 'C']
# Fitness score:  0.05618754313797586
# Total distance:  17.797539172417082
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'D', 'C', 'A', 'F']
# Fitness score:  0.05285232140206281
# Total distance:  18.920644798034743
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'C', 'D', 'B', 'F', 'E']
# Fitness score:  0.06610694996833429
# Total distance:  15.127002538749819
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'E', 'A', 'B', 'F']
# Fitness score:  0.05492734493274117
# Total distance:  18.20586815591588
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'F', 'D']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'B', 'D', 'F', 'E']
# Fitness score:  0.07690002517554077
# Total distance:  13.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'F', 'A', 'B', 'E']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'E', 'C', 'B']
# Fitness score:  0.08019623409290354
# Total distance:  12.469413449533645
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'A', 'C']
# Fitness score:  0.0588100483735406
# Total distance:  17.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'F', 'C', 'D']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'A', 'C', 'F', 'B']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'F', 'C', 'D']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'C', 'B', 'E', 'A']
# Fitness score:  0.06635229915246606
# Total distance:  15.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'F', 'C', 'D', 'B']
# Fitness score:  0.05778627220387139
# Total distance:  17.305148123623123
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'B', 'E', 'D', 'C']
# Fitness score:  0.056546447797315755
# Total distance:  17.684576820534954
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'B', 'E', 'C', 'F']
# Fitness score:  0.06702745411757192
# Total distance:  14.919259774448749
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'A', 'F', 'B']
# Fitness score:  0.05995921294596142
# Total distance:  16.67800411091546
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'B', 'D', 'F', 'E']
# Fitness score:  0.07690002517554077
# Total distance:  13.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'E', 'D', 'A', 'C', 'B']
# Fitness score:  0.0635980648900126
# Total distance:  15.723748855085674
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'E', 'A']
# Fitness score:  0.05913244546351071
# Total distance:  16.91118965504441
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'E', 'B', 'C', 'F']
# Fitness score:  0.06256938371005648
# Total distance:  15.982257466909886
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'F', 'C', 'D', 'B']
# Fitness score:  0.05778627220387139
# Total distance:  17.305148123623123
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'B', 'C', 'E', 'D', 'A']
# Fitness score:  0.06598991657030905
# Total distance:  15.153830342163696
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'B', 'D', 'E']
# Fitness score:  0.06187946590620513
# Total distance:  16.16044976076179
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'F', 'A', 'C', 'E']
# Fitness score:  0.07748265453702059
# Total distance:  12.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'B', 'F', 'E', 'D']
# Fitness score:  0.06905548859942201
# Total distance:  14.48110816796639
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'C', 'A', 'E', 'F']
# Fitness score:  0.05516631874808398
# Total distance:  18.127002538749817
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'B', 'A']
# Fitness score:  0.07515887765462095
# Total distance:  13.305148123623125
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'F', 'D']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'E', 'C', 'B']
# Fitness score:  0.08019623409290354
# Total distance:  12.469413449533645
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'F', 'C', 'D', 'A']
# Fitness score:  0.06340886839949075
# Total distance:  15.77066466002461
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'A', 'D', 'B', 'F']
# Fitness score:  0.07408245086513239
# Total distance:  13.498473502456159
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'B', 'A', 'C', 'E']
# Fitness score:  0.09037918050115185
# Total distance:  11.06449510224598
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'A', 'D', 'E', 'B']
# Fitness score:  0.05950924434566456
# Total distance:  16.80411188203658
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'C', 'D', 'B', 'F', 'E']
# Fitness score:  0.06610694996833429
# Total distance:  15.127002538749819
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'F', 'C', 'D']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'B', 'A']
# Fitness score:  0.07515887765462095
# Total distance:  13.305148123623125
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'A', 'C']
# Fitness score:  0.0588100483735406
# Total distance:  17.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'A', 'F', 'D', 'E']
# Fitness score:  0.06680422972420694
# Total distance:  14.969112047670894
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'F', 'B', 'C']
# Fitness score:  0.05715273283243808
# Total distance:  17.496976092671314
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'F', 'B', 'C', 'A']
# Fitness score:  0.0678746357668627
# Total distance:  14.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'E', 'B', 'D', 'A']
# Fitness score:  0.06702745411757192
# Total distance:  14.91925977444875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'C', 'E', 'B']
# Fitness score:  0.07380195545922741
# Total distance:  13.54977647648455
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'E', 'A']
# Fitness score:  0.05913244546351071
# Total distance:  16.91118965504441
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'E', 'C', 'D', 'F']
# Fitness score:  0.0626899004408959
# Total distance:  15.95153275036385
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'A', 'F', 'D', 'B', 'C']
# Fitness score:  0.06554869944528284
# Total distance:  15.255832815336875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'C', 'A']
# Fitness score:  0.06742031777664981
# Total distance:  14.83232403787835
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'D', 'C', 'F']
# Fitness score:  0.07348409477262549
# Total distance:  13.608386999856233
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'F', 'A', 'D']
# Fitness score:  0.07202728790843992
# Total distance:  13.88362701190674
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'E', 'B', 'C', 'F']
# Fitness score:  0.06256938371005648
# Total distance:  15.982257466909886
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'A', 'E', 'D', 'C']
# Fitness score:  0.05143520651121048
# Total distance:  19.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'E', 'C', 'B']
# Fitness score:  0.08019623409290354
# Total distance:  12.469413449533645
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'E', 'A', 'B', 'F']
# Fitness score:  0.05492734493274117
# Total distance:  18.20586815591588
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'F', 'E']
# Fitness score:  0.07625548705484254
# Total distance:  13.113810410532231
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'F', 'A', 'C', 'E']
# Fitness score:  0.07748265453702059
# Total distance:  12.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'B', 'E', 'D', 'C']
# Fitness score:  0.056546447797315755
# Total distance:  17.684576820534954
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'C', 'B', 'E', 'A']
# Fitness score:  0.06635229915246606
# Total distance:  15.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'F', 'C', 'D', 'A']
# Fitness score:  0.06340886839949075
# Total distance:  15.77066466002461
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'F', 'A', 'B', 'C']
# Fitness score:  0.07196666758831272
# Total distance:  13.895321730339484
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'D', 'F']
# Fitness score:  0.06980606303522072
# Total distance:  14.325403217417506
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'E', 'A', 'F', 'B']
# Fitness score:  0.06177567737254013
# Total distance:  16.18760072786364
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'E', 'F']
# Fitness score:  0.06511921235193015
# Total distance:  15.356451097651517
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'F', 'A', 'C', 'E']
# Fitness score:  0.07748265453702059
# Total distance:  12.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'F', 'B', 'C', 'A']
# Fitness score:  0.0678746357668627
# Total distance:  14.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'F', 'A', 'C', 'E']
# Fitness score:  0.07748265453702059
# Total distance:  12.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'A', 'B', 'F', 'E']
# Fitness score:  0.07625548705484254
# Total distance:  13.113810410532231
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'B', 'A']
# Fitness score:  0.07515887765462095
# Total distance:  13.305148123623125
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'A', 'E', 'D', 'C']
# Fitness score:  0.05143520651121048
# Total distance:  19.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'D', 'F']
# Fitness score:  0.06980606303522072
# Total distance:  14.325403217417506
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'A', 'D', 'E', 'B']
# Fitness score:  0.05950924434566456
# Total distance:  16.80411188203658
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'E', 'A']
# Fitness score:  0.05913244546351071
# Total distance:  16.91118965504441
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'C', 'A', 'E', 'F']
# Fitness score:  0.05516631874808398
# Total distance:  18.127002538749817
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'A', 'E']
# Fitness score:  0.07322330470336312
# Total distance:  13.65685424949238
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'F', 'B', 'C', 'A']
# Fitness score:  0.0678746357668627
# Total distance:  14.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'A', 'D', 'E', 'B']
# Fitness score:  0.05950924434566456
# Total distance:  16.80411188203658
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'D', 'F']
# Fitness score:  0.06980606303522072
# Total distance:  14.325403217417506
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'F', 'B', 'C']
# Fitness score:  0.05715273283243808
# Total distance:  17.496976092671314
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'E', 'B', 'D', 'A']
# Fitness score:  0.06702745411757192
# Total distance:  14.91925977444875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'B', 'D', 'E']
# Fitness score:  0.06187946590620513
# Total distance:  16.16044976076179
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'C', 'D', 'B', 'E']
# Fitness score:  0.060814549307647944
# Total distance:  16.443433543200516
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'B', 'F', 'A', 'C', 'E']
# Fitness score:  0.07748265453702059
# Total distance:  12.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'E', 'B', 'D', 'A']
# Fitness score:  0.06702745411757192
# Total distance:  14.91925977444875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'E', 'A', 'F', 'D']
# Fitness score:  0.06906693291257748
# Total distance:  14.478708664619075
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'B', 'A', 'C', 'E']
# Fitness score:  0.09037918050115185
# Total distance:  11.06449510224598
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'A', 'F', 'C', 'D']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'F', 'E', 'D', 'C']
# Fitness score:  0.06109427489443207
# Total distance:  16.36814581608426
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'C', 'D', 'B', 'E']
# Fitness score:  0.060814549307647944
# Total distance:  16.443433543200516
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'F', 'D', 'A', 'E']
# Fitness score:  0.07322330470336312
# Total distance:  13.65685424949238
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'A', 'D', 'C', 'F', 'E']
# Fitness score:  0.07982104776960239
# Total distance:  12.528023972905327
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'B', 'E', 'D', 'C']
# Fitness score:  0.056546447797315755
# Total distance:  17.684576820534954
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'A', 'C', 'F']
# Fitness score:  0.06677490987603654
# Total distance:  14.97568475729039
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'F', 'D']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'F', 'A', 'C']
# Fitness score:  0.05953252971971519
# Total distance:  16.797539172417082
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'C', 'E', 'B']
# Fitness score:  0.07380195545922741
# Total distance:  13.54977647648455
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'D', 'B', 'C', 'E']
# Fitness score:  0.07744321495436342
# Total distance:  12.912687064829255
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'E', 'A', 'F', 'D']
# Fitness score:  0.06906693291257748
# Total distance:  14.478708664619075
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'C', 'B', 'E', 'A']
# Fitness score:  0.06635229915246606
# Total distance:  15.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'F', 'E', 'B', 'D']
# Fitness score:  0.06458861171513772
# Total distance:  15.482605577751235
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'F', 'D', 'B', 'A']
# Fitness score:  0.08440106331480882
# Total distance:  11.848191962583275
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'E', 'C', 'A']
# Fitness score:  0.06742031777664981
# Total distance:  14.83232403787835
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'F', 'C', 'E', 'B']
# Fitness score:  0.07380195545922741
# Total distance:  13.54977647648455
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'A', 'D', 'E', 'B']
# Fitness score:  0.05950924434566456
# Total distance:  16.80411188203658
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'C', 'E', 'A']
# Fitness score:  0.06309868042745481
# Total distance:  15.848191962583275
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'A', 'C', 'F', 'B']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'E', 'B', 'D', 'A']
# Fitness score:  0.06702745411757192
# Total distance:  14.91925977444875
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'D', 'B', 'A', 'C', 'E']
# Fitness score:  0.07892630935899886
# Total distance:  12.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'B', 'F', 'E', 'D']
# Fitness score:  0.06905548859942201
# Total distance:  14.48110816796639
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'D', 'A', 'B', 'C']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'D', 'E', 'C', 'B']
# Fitness score:  0.06497768726141044
# Total distance:  15.389898319663486
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'E', 'B', 'D', 'A']
# Fitness score:  0.06556039913727349
# Total distance:  15.253110309870939
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'B', 'A', 'C', 'F']
# Fitness score:  0.06677490987603654
# Total distance:  14.97568475729039
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'F', 'E', 'A', 'B']
# Fitness score:  0.06802907660186833
# Total distance:  14.699596848159135
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'F', 'E', 'D', 'C']
# Fitness score:  0.06109427489443207
# Total distance:  16.36814581608426
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'D', 'B', 'C', 'E']
# Fitness score:  0.07744321495436342
# Total distance:  12.912687064829255
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'A', 'F', 'D']
# Fitness score:  0.06292109064131851
# Total distance:  15.89292222699217
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'F', 'D', 'B', 'C']
# Fitness score:  0.06179689616581195
# Total distance:  16.182042498005465
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'A', 'D', 'B', 'F']
# Fitness score:  0.07408245086513239
# Total distance:  13.498473502456159
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'F', 'E', 'D', 'C']
# Fitness score:  0.06109427489443207
# Total distance:  16.36814581608426
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'D', 'E', 'C', 'A']
# Fitness score:  0.061930020735195136
# Total distance:  16.147257632544196
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'D', 'B', 'C', 'E']
# Fitness score:  0.07744321495436342
# Total distance:  12.912687064829255
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'F', 'C', 'D', 'A']
# Fitness score:  0.06340886839949075
# Total distance:  15.77066466002461
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'D', 'F', 'A', 'C', 'E']
# Fitness score:  0.07191081379431934
# Total distance:  13.906114355209759
# +++++++++++++++++++++++++++++++++++++++++++
# ...
# Fitness score:  0.06420684539065331
# Total distance:  15.574663323134882
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'A', 'C', 'D', 'E']
# Fitness score:  0.05995921294596142
# Total distance:  16.67800411091546
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'E', 'A', 'F', 'D']
# Fitness score:  0.06906693291257748
# Total distance:  14.478708664619075
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'E', 'A', 'B', 'C']
# Fitness score:  0.07365673380613015
# Total distance:  13.576491222541476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'A', 'B']
# Fitness score:  0.0798210477696024
# Total distance:  12.528023972905325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'A', 'C', 'B', 'D', 'E']
# Fitness score:  0.06420684539065331
# Total distance:  15.574663323134882
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'F', 'B', 'C']
# Fitness score:  0.05715273283243808
# Total distance:  17.496976092671314
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'A', 'B', 'E', 'F']
# Fitness score:  0.06773190002874242
# Total distance:  14.764091950405115
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'B', 'F', 'C']
# Fitness score:  0.05524090529813173
# Total distance:  18.102527368135302
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'A', 'B']
# Fitness score:  0.0798210477696024
# Total distance:  12.528023972905325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'F', 'D', 'A']
# Fitness score:  0.0775224150181086
# Total distance:  12.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'E', 'B', 'C', 'F']
# Fitness score:  0.06256938371005648
# Total distance:  15.982257466909886
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'F', 'B', 'E', 'C']
# Fitness score:  0.06711636899468035
# Total distance:  14.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'D', 'B', 'A', 'F']
# Fitness score:  0.07249974478340757
# Total distance:  13.79315200332763
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'F', 'D', 'A']
# Fitness score:  0.0775224150181086
# Total distance:  12.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'C', 'B', 'E', 'A']
# Fitness score:  0.06635229915246606
# Total distance:  15.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'F', 'A', 'D', 'C']
# Fitness score:  0.06026812417516423
# Total distance:  16.592519075151305
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'E', 'F', 'D', 'A']
# Fitness score:  0.07556668131375462
# Total distance:  13.233345472033855
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'F', 'C', 'D', 'A', 'B']
# Fitness score:  0.0798210477696024
# Total distance:  12.528023972905325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'C', 'E', 'B', 'D', 'F']
# Fitness score:  0.06284293758344767
# Total distance:  15.912687064829255
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'F', 'E', 'A', 'B']
# Fitness score:  0.06802907660186833
# Total distance:  14.699596848159135
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'F', 'B', 'E', 'C']
# Fitness score:  0.06711636899468035
# Total distance:  14.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'E', 'B', 'C', 'F']
# Fitness score:  0.06256938371005648
# Total distance:  15.982257466909886
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'F', 'E', 'A', 'B']
# Fitness score:  0.061404756796409256
# Total distance:  16.28538328578604
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'A', 'B', 'E', 'F']
# Fitness score:  0.06773190002874242
# Total distance:  14.764091950405115
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'B', 'A', 'E', 'F']
# Fitness score:  0.05920335528941829
# Total distance:  16.890934561250027
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'C', 'E', 'F', 'D']
# Fitness score:  0.08768146948091228
# Total distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'C', 'F', 'D', 'A']
# Fitness score:  0.06986309663012404
# Total distance:  14.313708498984761
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'C', 'E', 'F', 'D', 'A']
# Fitness score:  0.07556668131375462
# Total distance:  13.233345472033855
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'B', 'A', 'C', 'D', 'E']
# Fitness score:  0.06475871881350707
# Total distance:  15.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'B', 'F', 'C']
# Fitness score:  0.05524090529813173
# Total distance:  18.102527368135302
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'F', 'E', 'D', 'C']
# Fitness score:  0.06109427489443207
# Total distance:  16.36814581608426
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'A', 'D', 'F', 'C']
# Fitness score:  0.0606601717798213
# Total distance:  16.485281374238568
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'C', 'B', 'E', 'A']
# Fitness score:  0.06635229915246606
# Total distance:  15.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'B', 'A', 'E', 'F']
# Fitness score:  0.05920335528941829
# Total distance:  16.890934561250027
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'B', 'A', 'F', 'D']
# Fitness score:  0.07514765129241226
# Total distance:  13.307135789365265
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'E', 'D', 'F', 'B', 'C']
# Fitness score:  0.05715273283243808
# Total distance:  17.496976092671314
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'E', 'A', 'C', 'F', 'B']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'C', 'D', 'B', 'A', 'F']
# Fitness score:  0.07249974478340757
# Total distance:  13.79315200332763
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'A', 'C', 'D', 'E']
# Fitness score:  0.05995921294596142
# Total distance:  16.67800411091546
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'A', 'D', 'F', 'C']
# Fitness score:  0.0606601717798213
# Total distance:  16.485281374238568
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'E', 'D', 'A']
# Fitness score:  0.06256938371005649
# Total distance:  15.982257466909884
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'E', 'A', 'F', 'B']
# Fitness score:  0.05143520651121048
# Total distance:  19.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'F', 'E', 'A', 'B', 'C']
# Fitness score:  0.07365673380613015
# Total distance:  13.576491222541476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'D', 'F', 'B', 'A']
# Fitness score:  0.06706373020087657
# Total distance:  14.91118965504441
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'A', 'B', 'E', 'F']
# Fitness score:  0.06773190002874242
# Total distance:  14.764091950405115
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'A', 'B', 'E', 'F']
# Fitness score:  0.06773190002874242
# Total distance:  14.764091950405115
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'D', 'A', 'F']
# Fitness score:  0.06736522166192135
# Total distance:  14.84445497735602
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'F', 'B', 'A', 'D', 'E']
# Fitness score:  0.07504463344815784
# Total distance:  13.325403217417506
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'E', 'A', 'C', 'D']
# Fitness score:  0.06052737039040948
# Total distance:  16.52145126328583
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'C', 'F', 'D']
# Fitness score:  0.08009431025426017
# Total distance:  12.485281374238571
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'F', 'D', 'A']
# Fitness score:  0.0775224150181086
# Total distance:  12.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'C', 'B', 'A', 'F']
# Fitness score:  0.06731219195263409
# Total distance:  14.856149695788766
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'E', 'A', 'F', 'B']
# Fitness score:  0.06177567737254013
# Total distance:  16.18760072786364
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'E', 'A', 'F', 'B']
# Fitness score:  0.06177567737254013
# Total distance:  16.18760072786364
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'A', 'E', 'C', 'B', 'F']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'D', 'F', 'B', 'C', 'A']
# Fitness score:  0.0678746357668627
# Total distance:  14.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'B', 'E', 'A', 'F', 'D']
# Fitness score:  0.06292109064131851
# Total distance:  15.89292222699217
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'A', 'C', 'D', 'E']
# Fitness score:  0.05995921294596142
# Total distance:  16.67800411091546
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['D', 'C', 'F', 'A', 'B', 'E']
# Fitness score:  0.07682835434310253
# Total distance:  13.016027852609831
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'F', 'D', 'A']
# Fitness score:  0.0775224150181086
# Total distance:  12.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'D', 'C', 'E', 'B', 'F']
# Fitness score:  0.06241184108136212
# Total distance:  16.022600562229325
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'A', 'E', 'D']
# Fitness score:  0.05976198925948173
# Total distance:  16.733044070171104
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'E', 'C', 'F', 'D', 'A']
# Fitness score:  0.06986309663012404
# Total distance:  14.313708498984761
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['B', 'F', 'C', 'E', 'A', 'D']
# Fitness score:  0.07106781186547524
# Total distance:  14.071067811865476
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['E', 'B', 'C', 'F', 'D', 'A']
# Fitness score:  0.0775224150181086
# Total distance:  12.899494936611665
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['F', 'C', 'B', 'D', 'E', 'A']
# Fitness score:  0.05708824512317409
# Total distance:  17.516740930508398
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['A', 'B', 'E', 'D', 'C', 'F']
# Fitness score:  0.05930240538617164
# Total distance:  16.86272240540826
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'E', 'A', 'F', 'D', 'B']
# Fitness score:  0.05998783550699239
# Total distance:  16.67004637770997
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'D', 'E', 'A', 'F', 'B']
# Fitness score:  0.05143520651121048
# Total distance:  19.44193613341567
# +++++++++++++++++++++++++++++++++++++++++++
# Child after mutation: ['C', 'A', 'B', 'D', 'F', 'E']
# Fitness score:  0.07690002517554077
# Total distance:  13.00389691313216
# +++++++++++++++++++++++++++++++++++++++++++
# Best individual: ['A', 'B', 'C', 'E', 'F', 'D']
# Best fitness score: 0.08768146948091228
# Total best distance:  11.404918347287666
# +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## References
# - [Introduction to Genetic Algorithms. Vijini Mallawaarachchi.](https://towardsdatascience.com/introduction-to-genetic-algorithms-including-example-code-e396e98d8bf3)
# - Mykel J. Kochenderfer and Tim A. Wheeler (2019).
# Algorithms for Optimization.
# Massachusetts Institute of Technology, 148-156.
